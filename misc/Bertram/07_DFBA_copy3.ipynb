# %% [markdown]
# ## Dynamic Flux Based Analysis
#
# Calculating a single number for the progesterone yield and flux - as we mostly do during this report - gives little information about what the final titres will be.
# To get a better idea of how the progesterone and biomass titres change over time, it can be insightful to mimick real conditions by simulating a simple batch fermentation. This is the purpose of Dynamic Flux Based Analysis (DFBA)
#
# We used cobra and dfba packages to make a DFBA and simulate a batch fermentation in defined intitial conditions. The code is run in the following steps:
#  - Load libraries and model
#  - Calculcate optimal fluxes for biomass and progesterone and adjust the lowerbound for progesterone.
#  - Make DFBA model
#  - Add Kinetic variables
#  - Add Exchange Fluxes
#  - Add right-hand-side expressions (rhs) for kinetic variables
#  - Lower/upper bound expressions for exchange fluxes
#  - Define initial conditions
#  - Run simulation and plot concentrations and trajectories.
#  - Investigate relationship between initial glucose concentration and final progesterone titre
#
# It is important to note, that this code requires another version of python than our other scripts are running. It might therefore be necessary to make a new environment with python version 3.7 and install the dfba package in order to run this script. In ubuntu, you can use the quoted code below.

# %%
#Create an environment to install dfba and run this script.

# conda create --name dfba python=3.7
# conda activate dfba
# conda install -c conda-forge dfba

# %%
# Load libraries
from cobra.io import read_sbml_model
from dfba.plot.matplotlib import *
from dfba import DfbaModel, ExchangeFlux, KineticVariable

# %%
# Loading model
infilename = '../../models/iMM904_progesterone.xml'
print(f"Loading {infilename}")
model = read_sbml_model(infilename)
# Out:
# Loading ../../models/iMM904_progesterone.xml

# %% [markdown]
# To ensure that our strain can grow while producing progesterone, we find the optimal progesterone productivity and growth rate (see 03_maximum theoretical yield). To simulate the optimal model in steady state, we define a progesterone productivity from the obtained results:

# %%
# max growth rate and max progesterone productivity
with model:
    baseline_max_growth = model.optimize().objective_value
    model.objective = model.reactions.DM_progesterone_c
    baseline_max_production = model.optimize().objective_value
print(f"Maximum growth rate: {baseline_max_growth} gDW/h")
print(f"Maximum progesterone production: {baseline_max_production} mmol/gDW*h")
# Out:
# Maximum growth rate: 0.287865703704015 gDW/h
# Maximum progesterone production: 0.16666666666666655 mmol/gDW*h

# %%
# growth and progesterone productivity when both are set to be objective
with model:
    model.objective = {model.reactions.get_by_id('BIOMASS_SC5_notrace'): baseline_max_production, 
                    model.reactions.get_by_id('DM_progesterone_c'): baseline_max_growth} # objective is to lead flux through the reaction producing progesterone top maximise production
    solution = model.optimize()
    growth = solution.fluxes['BIOMASS_SC5_notrace']
    progesterone = solution.fluxes['DM_progesterone_c'] #*1000 /314.46
    o_uptake = solution.fluxes['EX_o2_e']
    glc_uptake = solution.fluxes['EX_glc__D_e']
    print(f"Growth rate in complete model: {growth} gDW/h")
    print(f"Progesterone productivity in complete model: {progesterone} mmol/gDW*h")
    print(f"Growth rate in complete model: {growth} gDW/h")
    print(f"Progesterone productivity in complete model: {progesterone} mmol/gDW*h")
# Out:
# Growth rate in complete model: 0.11872292252086913 gDW/h
# Progesterone productivity in complete model: 0.15620047742340093 mmol/gDW*h
# Growth rate in complete model: 0.11872292252086913 gDW/h
# Progesterone productivity in complete model: 0.15620047742340093 mmol/gDW*h

# %% [markdown]
# Now we have calculated the optimal fluxes for progesterone and biomass when they are both set to the objective for the model. Unfortunately, this DFBA simulation does not work when two reactions are set as the objective.
# Therefore, we chose to keep biomass as the objective and then force the progesterone flux to the value ~0.156 mmol/(gDW*h), as calculated above.

# %%
# Setting progesterone productivity constant
#progesterone_gh = progesterone * 1000 / 314.46 # calculate progesterone productivity in g/gDW*h
#print(f"Setting progesterone productivity to: {progesterone_gh} g/gDW*h")

model.reactions.DM_progesterone_c.lower_bound = progesterone
print(f"Setting progesterone productivity to: {progesterone} g/gDW*h")
SQLR_flux = model.optimize()['SQLS'] #0.15646166785294682}
print(f"Test: {SQLR_flux}")
# Out:
# Setting progesterone productivity to: 0.15620047742340093 g/gDW*h
# Test: 0.15646166785294682

# %% [markdown]
# Now we have defined the model as it should be for batch simulation. Then we can start defining the kinetic variables, exchange fluxes, and equations that we are using in the simulation.

# %%
model.solver = "glpk"
dfba_model = DfbaModel(model)

# %%
model.reactions.SQLS
# Out:
# <Reaction SQLS at 0x7fe0798b7e90>

# %%
# instances of KineticVariable
X = KineticVariable("Biomass")
Gluc = KineticVariable("Glucose")
Sqr = KineticVariable("Squalene")

# add kinetic variables to dfba_model
dfba_model.add_kinetic_variables([X, Gluc, Sqr])

# %%
# instances of ExchangeFlux
mu = ExchangeFlux("BIOMASS_SC5_notrace")
v_G = ExchangeFlux("EX_glc__D_e")
v_O = ExchangeFlux("EX_o2_e")
v_P = ExchangeFlux("SQLS")

# add exchange fluxes to dfba_model
dfba_model.add_exchange_fluxes([mu, v_G, v_O, v_P]) #v_O

# %%
# add rhs expressions for kinetic variables in dfba_model
Vgmax = 8.5
Kg = 0.5
#Gin = 100.0
Vomax = 8.0

#This is flux terms:
#dfba_model.add_rhs_expression("Volume", D)
#dfba_model.add_rhs_expression("Oxygen", 0) #keep O2 constant
dfba_model.add_rhs_expression("Biomass", mu * X )
dfba_model.add_rhs_expression("Glucose", v_G * X )#* 180.1559 / 1000 ) #+ D * (Gin - Gluc) / V
dfba_model.add_rhs_expression("Squalene", v_P * X )# ) # - D * Pro / V

# %%
# add lower/upper bound expressions for exchange fluxes in dfba_model together
# with expression that must be non-negative for correct evaluation of bounds
dfba_model.add_exchange_flux_lb("EX_glc__D_e", Vgmax * (Gluc / (Kg + Gluc)), Gluc)

Oxy = 2
vmax_o2 = 15 # [mmol gDW^-1 h^-1]
Ko = 0.024 # mmol/L O2 Michaelis-Mentent constant
dfba_model.add_exchange_flux_lb("EX_o2_e", vmax_o2 * (Oxy / (Ko + Oxy)), Oxy)
dfba_model.add_exchange_flux_lb("EX_glc__D_e", Vgmax * (Gluc / (Kg + Gluc)), Gluc)

# %%
# add initial conditions for kinetic variables in dfba_model biomass (gDW/L),
# metabolites in mmol/L

dfba_model.add_initial_conditions(
    {
        "Biomass": 0.05,
        "Glucose": 10,
        "Squalene": 0
    }
)

# %%
# simulate model across interval t = [0.0,16.0](hours) with outputs for plotting
# every 0.1h
concentrations, trajectories = dfba_model.simulate(0.0, 100, 0.1, ["BIOMASS_SC5_notrace", "EX_glc__D_e", "SQLS"])
# Out:
# cc1plus: warning: command line option '-Wstrict-prototypes' is valid for C/ObjC but not for C++
# Final Run Statistics:
#
# Number of steps                    = 29
# Number of residual evaluations     = 96
# Number of Jacobian evaluations     = 17
# Number of nonlinear iterations     = 46
# Number of error test failures      = 5
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 87
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 18
# Number of Jacobian evaluations     = 5
# Number of nonlinear iterations     = 9
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 18
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 21
# Number of residual evaluations     = 66
# Number of Jacobian evaluations     = 10
# Number of nonlinear iterations     = 33
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 33
#
#
# Final Run Statistics:
#
# Number of steps                    = 15
# Number of residual evaluations     = 40
# Number of Jacobian evaluations     = 12
# Number of nonlinear iterations     = 20
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 29
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 22
# Number of Jacobian evaluations     = 5
# Number of nonlinear iterations     = 11
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 20
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 5
# Number of residual evaluations     = 14
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 7
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 17
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 10
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 22
# Number of Jacobian evaluations     = 5
# Number of nonlinear iterations     = 11
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 20
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 11
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 22
# Number of Jacobian evaluations     = 5
# Number of nonlinear iterations     = 11
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 20
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 2
# Number of residual evaluations     = 6
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 3
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 13
#
#
# Final Run Statistics:
#
# Number of steps                    = 6
# Number of residual evaluations     = 20
# Number of Jacobian evaluations     = 5
# Number of nonlinear iterations     = 10
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 18
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 8
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 4
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 2
# Number of residual evaluations     = 10
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 5
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 13
#
#
# Final Run Statistics:
#
# Number of steps                    = 4
# Number of residual evaluations     = 10
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 5
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 16
#
#
# Final Run Statistics:
#
# Number of steps                    = 6
# Number of residual evaluations     = 20
# Number of Jacobian evaluations     = 5
# Number of nonlinear iterations     = 10
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 18
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 8
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 4
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 4
# Number of residual evaluations     = 14
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 7
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 15
#
#
# Final Run Statistics:
#
# Number of steps                    = 2
# Number of residual evaluations     = 10
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 5
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 13
#
#
# Final Run Statistics:
#
# Number of steps                    = 6
# Number of residual evaluations     = 18
# Number of Jacobian evaluations     = 4
# Number of nonlinear iterations     = 9
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 18
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 4
# Number of residual evaluations     = 10
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 5
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 16
#
#
# Final Run Statistics:
#
# Number of steps                    = 4
# Number of residual evaluations     = 10
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 5
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 16
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 9
#
#
# Final Run Statistics:
#
# Number of steps                    = 11
# Number of residual evaluations     = 36
# Number of Jacobian evaluations     = 8
# Number of nonlinear iterations     = 18
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 21
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 10
#
#
# Final Run Statistics:
#
# Number of steps                    = 17
# Number of residual evaluations     = 50
# Number of Jacobian evaluations     = 6
# Number of nonlinear iterations     = 25
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 28
#
# Basis not feasible with primal status 4
#
# Final Run Statistics:
#
# Number of steps                    = 17
# Number of residual evaluations     = 50
# Number of Jacobian evaluations     = 6
# Number of nonlinear iterations     = 25
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 28
#
# Total simulation time was 11.9688 seconds

# %%
# plotting concentration in steady state
plot_concentrations(concentrations)
plt.title(" \n Batch fermentation simulation \n", size=15)
#plt.savefig('figures/07_Bacth_fermentation_simul.png',bbox_inches='tight')
# Out:
# Text(0.5, 1.0, ' \n Batch fermentation simulation \n')

# %%
# printing concentrations in steady state
concentrations
# Out:
#     time   Biomass    Glucose  Squalene
# 0    0.0  0.050000  10.000000  0.000000
# 1    0.1  0.052701   9.958440  0.000808
# 2    0.2  0.055550   9.914620  0.001660
# 3    0.3  0.058559   9.868340  0.002560
# 4    0.4  0.061729   9.819586  0.003509
# 5    0.5  0.065097   9.767794  0.004516
# 6    0.6  0.068657   9.713067  0.005582
# 7    0.7  0.072407   9.655445  0.006704
# 8    0.8  0.076345   9.594928  0.007882
# 9    0.9  0.080535   9.530553  0.009137
# 10   1.0  0.084958   9.462615  0.010461
# 11   1.1  0.089603   9.391296  0.011852
# 12   1.2  0.094468   9.316597  0.013309
# 13   1.3  0.099643   9.237178  0.014859
# 14   1.4  0.105119   9.153167  0.016499
# 15   1.5  0.110868   9.064994  0.018222
# 16   1.6  0.116889   8.972657  0.020026
# 17   1.7  0.123278   8.874742  0.021941
# 18   1.8  0.130050   8.770994  0.023972
# 19   1.9  0.137160   8.662106  0.026104
# 20   2.0  0.144609   8.548081  0.028338
# 21   2.1  0.152449   8.428113  0.030691
# 22   2.2  0.160733   8.301429  0.033177
# 23   2.3  0.169443   8.168312  0.035792
# 24   2.4  0.178593   8.028530  0.038540
# 25   2.5  0.188225   7.881489  0.041434
# 26   2.6  0.198395   7.726381  0.044491
# 27   2.7  0.209104   7.563184  0.047711
# 28   2.8  0.220376   7.391535  0.051103
# 29   2.9  0.232244   7.210997  0.054675
# 30   3.0  0.244750   7.021019  0.058443
# 31   3.1  0.257912   6.821304  0.062410
# 32   3.2  0.271759   6.611453  0.066587
# 33   3.3  0.286327   6.390986  0.070986
# 34   3.4  0.301682   6.159149  0.075627
# 35   3.5  0.317838   5.915669  0.080516
# 36   3.6  0.334830   5.660089  0.085663
# 37   3.7  0.352693   5.391963  0.091081
# 38   3.8  0.371476   5.110938  0.096788
# 39   3.9  0.391208   4.816520  0.102791
# 40   4.0  0.411935   4.508461  0.109111
# 41   4.1  0.433702   4.186530  0.115766
# 42   4.2  0.456547   3.850303  0.122768
# 43   4.3  0.480503   3.500195  0.130139
# 44   4.4  0.505602   3.136335  0.137894
# 45   4.5  0.531859   2.759811  0.146053
# 46   4.6  0.559278   2.372100  0.154633
# 47   4.7  0.587827   1.976125  0.163653
# 48   4.8  0.617422   1.577008  0.173130
# 49   4.9  0.647032   1.183230  0.183076
# 50   5.0  0.674161   0.810743  0.193455
# 51   5.1  0.696328   0.485088  0.204215
# 52   5.2  0.710368   0.239439  0.215245

# %% [markdown]
# As seen in the figure and table above, the batch fermentaiton ran for 5.2 hours before all of the glucose got consumed. The final progesterone titre reached 0.21 mmol/L (corresponding to 0.067 g/L)
# The biomass reached 0.71 gDW/L

# %%
# Plotting fluxes at steady state
plot_trajectories(trajectories)
plt.title("\n Fluxes for batch fermentation simulation \n", size=15)
# Out:
# Text(0.5, 1.0, '\n Fluxes for batch fermentation simulation \n')

# %%
# printing fluxes at steady state
trajectories
# Out:
#     time  BIOMASS_SC5_notrace  EX_glc__D_e  DM_progesterone_c
# 0    0.0             0.000000     0.000000             0.0000
# 1    0.1             0.526086    -8.093630             0.1562
# 2    0.2             0.526046    -8.091920             0.1562
# 3    0.3             0.526003    -8.090098             0.1562
# 4    0.4             0.525957    -8.088162             0.1562
# 5    0.5             0.525907    -8.086084             0.1562
# 6    0.6             0.525854    -8.083866             0.1562
# 7    0.7             0.525798    -8.081505             0.1562
# 8    0.8             0.525739    -8.078996             0.1562
# 9    0.9             0.525675    -8.076295             0.1562
# 10   1.0             0.525606    -8.073405             0.1562
# 11   1.1             0.525533    -8.070329             0.1562
# 12   1.2             0.525455    -8.067060             0.1562
# 13   1.3             0.525371    -8.063529             0.1562
# 14   1.4             0.525281    -8.059730             0.1562
# 15   1.5             0.525185    -8.055671             0.1562
# 16   1.6             0.525082    -8.051340             0.1562
# 17   1.7             0.524970    -8.046654             0.1562
# 18   1.8             0.524850    -8.041581             0.1562
# 19   1.9             0.524720    -8.036133             0.1562
# 20   2.0             0.524582    -8.030287             0.1562
# 21   2.1             0.524432    -8.023976             0.1562
# 22   2.2             0.524269    -8.017124             0.1562
# 23   2.3             0.524093    -8.009708             0.1562
# 24   2.4             0.523902    -8.001673             0.1562
# 25   2.5             0.523694    -7.992930             0.1562
# 26   2.6             0.523467    -7.983369             0.1562
# 27   2.7             0.523218    -7.972913             0.1562
# 28   2.8             0.522946    -7.961448             0.1562
# 29   2.9             0.522647    -7.948839             0.1562
# 30   3.0             0.522316    -7.934917             0.1562
# 31   3.1             0.521950    -7.919502             0.1562
# 32   3.2             0.521543    -7.902372             0.1562
# 33   3.3             0.521088    -7.883252             0.1562
# 34   3.4             0.520578    -7.861780             0.1562
# 35   3.5             0.520003    -7.837559             0.1562
# 36   3.6             0.519350    -7.810075             0.1562
# 37   3.7             0.518604    -7.778678             0.1562
# 38   3.8             0.517746    -7.742551             0.1562
# 39   3.9             0.516749    -7.700605             0.1562
# 40   4.0             0.515581    -7.651436             0.1562
# 41   4.1             0.514196    -7.593146             0.1562
# 42   4.2             0.512531    -7.523057             0.1562
# 43   4.3             0.510499    -7.437552             0.1562
# 44   4.4             0.507974    -7.331241             0.1562
# 45   4.5             0.504766    -7.196243             0.1562
# 46   4.6             0.500585    -7.020247             0.1562
# 47   4.7             0.494963    -6.783609             0.1562
# 48   4.8             0.487127    -6.453787             0.1562
# 49   4.9             0.443752    -5.975092             0.1562
# 50   5.0             0.373238    -5.257565             0.1562
# 51   5.1             0.267897    -4.185666             0.1562
# 52   5.2             0.127044    -2.752399             0.1562

# %% [markdown]
# In this simulation, the fluxes changes rapidly in the beginning, representing the speed of which glucose is consumed while biomass and progesterone is produced. The negative value for glucose means that it is removed from the media when it is consumed by *S. cerevisiae*. In constrast, the positive values for biomass and progesterone means that it is produced.
#
# When glucose starts to become limited after 5 hours, the glucose flux increases, i.e. it is consumed at a lower rate. It doesn't seem to affect the growth until after approximately 4 hours.
#
# Progesterone is obviously produced at low levels with a constant flux of 0.1562, since we had to define this as constant due to the issues of running the simulation when the model had two objects. Therefore, the progesterone levels do not decrease as a consequence of the decreasing glucose and biomass levels. This would most certainly not be the case in real life, but is the best solution we have for the current tools we are using. One could also decide to set the progeterone production as the objective and then the biomass production to a constant optimal level, and the model would then show that progesterone production decrased as a consequence of decreasing glucose.
#
# To make a better simulation in the future, it would be necessary to have two objectives for the simulation. It could then be interesting to test how the different concentrations of oxygen and glucose could affect growth and progesterone production. As we have found optimal levels for these substrates (see 04_phenotypic_phase_plane_analysis.ipynb), it is likely that a fed-batch simulation would give a higher progesterone titre, since this would allow keeping the glucose concentration more constant and closer to its optimal level during the simulation.

# %% [markdown]
# In the following code, we test how much we can increase the progesterone titre by adding more glucose initially.

# %%
# Make list manually
Prog = []
Glc = [4,36,60,100]

# %%
from matplotlib import pyplot as plt

# %%
with model:
    model.objective = {model.reactions.get_by_id('BIOMASS_SC5_notrace'): baseline_max_production, 
                    model.reactions.get_by_id('DM_progesterone_c'): baseline_max_growth} # objective is to lead flux through the reaction producing progesterone top maximise production
    solution = model.optimize()
    growth = solution.fluxes['BIOMASS_SC5_notrace']
    progesterone = solution.fluxes['DM_progesterone_c'] #*1000 /314.46
    o_uptake = solution.fluxes['EX_o2_e']
    glc_uptake = solution.fluxes['EX_glc__D_e']
    print(f"Growth rate in complete model: {growth} gDW/h")
    print(f"Progesterone productivity in complete model: {progesterone} mmol/gDW*h")
    print(f"Growth rate in complete model: {growth} gDW/h")
    print(f"Progesterone productivity in complete model: {progesterone} mmol/gDW*h")
# Out:
# Growth rate in complete model: 0.11872292252085902 gDW/h
# Progesterone productivity in complete model: 0.15620047742340107 mmol/gDW*h
# Growth rate in complete model: 0.11872292252085902 gDW/h
# Progesterone productivity in complete model: 0.15620047742340107 mmol/gDW*h

# %%
dfba_result = {}

Vgmax = 8.5
Kg = 0.5
Vomax = 8.0
Oxy = 2
vmax_o2 = 15 
Ko = 0.024 
for glucose in Glc:
    with model:
        model.reactions.DM_progesterone_c.lower_bound = progesterone
        model.solver = "glpk"
        dfba_model = DfbaModel(model)
        X = KineticVariable("Biomass")
        Gluc = KineticVariable("Glucose")
        Pro = KineticVariable("Progesterone")
        # add kinetic variables to dfba_model
        dfba_model.add_kinetic_variables([X, Gluc, Pro])

        mu = ExchangeFlux("BIOMASS_SC5_notrace")
        v_G = ExchangeFlux("EX_glc__D_e")
        v_O = ExchangeFlux("EX_o2_e")
        v_P = ExchangeFlux("DM_progesterone_c")
        # add exchange fluxes to dfba_model
        dfba_model.add_exchange_fluxes([mu, v_G, v_O, v_P])

        dfba_model.add_rhs_expression("Biomass", mu * X )
        dfba_model.add_rhs_expression("Glucose", v_G * X )
        dfba_model.add_rhs_expression("Progesterone", v_P * X )
        dfba_model.add_exchange_flux_lb("EX_glc__D_e", Vgmax * (Gluc / (Kg + Gluc)), Gluc)

        dfba_model.add_exchange_flux_lb("EX_o2_e", vmax_o2 * (Oxy / (Ko + Oxy)), Oxy)
        dfba_model.add_exchange_flux_lb("EX_glc__D_e", Vgmax * (Gluc / (Kg + Gluc)), Gluc)
        dfba_model.add_initial_conditions(
            {
                "Biomass": 0.05,
                "Glucose": glucose,
                "Progesterone": 0
            }
        )
        conc, traj = dfba_model.simulate(0.0, 100, 0.1, ["BIOMASS_SC5_notrace", "EX_glc__D_e", "DM_progesterone_c"])
        Prog.append(list(conc.Progesterone)[-1])
# Out:
# cc1plus: warning: command line option '-Wstrict-prototypes' is valid for C/ObjC but not for C++
# Final Run Statistics:
#
# Number of steps                    = 25
# Number of residual evaluations     = 78
# Number of Jacobian evaluations     = 16
# Number of nonlinear iterations     = 37
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 61
#
#
# Final Run Statistics:
#
# Number of steps                    = 2
# Number of residual evaluations     = 6
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 3
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 13
#
#
# Final Run Statistics:
#
# Number of steps                    = 9
# Number of residual evaluations     = 20
# Number of Jacobian evaluations     = 7
# Number of nonlinear iterations     = 10
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 19
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 26
# Number of residual evaluations     = 78
# Number of Jacobian evaluations     = 12
# Number of nonlinear iterations     = 39
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 44
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 10
# Number of residual evaluations     = 26
# Number of Jacobian evaluations     = 8
# Number of nonlinear iterations     = 13
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 20
#
#
# Final Run Statistics:
#
# Number of steps                    = 9
# Number of residual evaluations     = 26
# Number of Jacobian evaluations     = 7
# Number of nonlinear iterations     = 13
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 22
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 18
# Number of Jacobian evaluations     = 5
# Number of nonlinear iterations     = 9
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 20
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 8
# Number of residual evaluations     = 22
# Number of Jacobian evaluations     = 6
# Number of nonlinear iterations     = 11
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 18
#
#
# Final Run Statistics:
#
# Number of steps                    = 9
# Number of residual evaluations     = 26
# Number of Jacobian evaluations     = 7
# Number of nonlinear iterations     = 13
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 22
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 5
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 17
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 18
# Number of Jacobian evaluations     = 5
# Number of nonlinear iterations     = 9
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 19
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 4
# Number of residual evaluations     = 10
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 5
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 16
#
#
# Final Run Statistics:
#
# Number of steps                    = 6
# Number of residual evaluations     = 14
# Number of Jacobian evaluations     = 4
# Number of nonlinear iterations     = 7
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 17
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 18
# Number of Jacobian evaluations     = 5
# Number of nonlinear iterations     = 9
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 20
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 5
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 17
#
#
# Final Run Statistics:
#
# Number of steps                    = 3
# Number of residual evaluations     = 8
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 4
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 15
#
#
# Final Run Statistics:
#
# Number of steps                    = 9
# Number of residual evaluations     = 24
# Number of Jacobian evaluations     = 7
# Number of nonlinear iterations     = 12
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 22
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 11
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 16
# Number of Jacobian evaluations     = 5
# Number of nonlinear iterations     = 8
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 19
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 16
# Number of Jacobian evaluations     = 5
# Number of nonlinear iterations     = 8
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 19
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 12
# Number of residual evaluations     = 32
# Number of Jacobian evaluations     = 8
# Number of nonlinear iterations     = 16
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 24
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 14
# Number of Jacobian evaluations     = 5
# Number of nonlinear iterations     = 7
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 17
#
#
# Final Run Statistics:
#
# Number of steps                    = 27
# Number of residual evaluations     = 72
# Number of Jacobian evaluations     = 16
# Number of nonlinear iterations     = 36
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 38
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 2
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 1
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 10
#
# Basis not feasible with primal status 4
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 2
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 1
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 10
#
# Total simulation time was 17.2813 seconds
# cc1plus: warning: command line option '-Wstrict-prototypes' is valid for C/ObjC but not for C++
# Final Run Statistics:
#
# Number of steps                    = 35
# Number of residual evaluations     = 140
# Number of Jacobian evaluations     = 18
# Number of nonlinear iterations     = 68
# Number of error test failures      = 9
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 115
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 24
# Number of Jacobian evaluations     = 6
# Number of nonlinear iterations     = 12
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 19
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 8
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 4
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 10
#
#
# Final Run Statistics:
#
# Number of steps                    = 19
# Number of residual evaluations     = 66
# Number of Jacobian evaluations     = 7
# Number of nonlinear iterations     = 33
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 24
#
#
# Final Run Statistics:
#
# Number of steps                    = 9
# Number of residual evaluations     = 30
# Number of Jacobian evaluations     = 8
# Number of nonlinear iterations     = 15
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 21
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 8
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 4
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 8
# Number of residual evaluations     = 28
# Number of Jacobian evaluations     = 8
# Number of nonlinear iterations     = 14
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 20
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 8
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 4
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 10
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 24
# Number of Jacobian evaluations     = 7
# Number of nonlinear iterations     = 12
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 19
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 8
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 4
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 24
# Number of Jacobian evaluations     = 7
# Number of nonlinear iterations     = 12
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 19
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 10
#
#
# Final Run Statistics:
#
# Number of steps                    = 2
# Number of residual evaluations     = 6
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 3
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 6
# Number of residual evaluations     = 20
# Number of Jacobian evaluations     = 5
# Number of nonlinear iterations     = 10
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 17
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 8
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 4
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 9
#
#
# Final Run Statistics:
#
# Number of steps                    = 2
# Number of residual evaluations     = 10
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 5
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 4
# Number of residual evaluations     = 10
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 5
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 14
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 24
# Number of Jacobian evaluations     = 8
# Number of nonlinear iterations     = 12
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 18
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 9
#
#
# Final Run Statistics:
#
# Number of steps                    = 6
# Number of residual evaluations     = 22
# Number of Jacobian evaluations     = 7
# Number of nonlinear iterations     = 11
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 17
#
#
# Final Run Statistics:
#
# Number of steps                    = 3
# Number of residual evaluations     = 16
# Number of Jacobian evaluations     = 4
# Number of nonlinear iterations     = 8
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 11
#
#
# Final Run Statistics:
#
# Number of steps                    = 6
# Number of residual evaluations     = 18
# Number of Jacobian evaluations     = 4
# Number of nonlinear iterations     = 9
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 17
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 4
# Number of residual evaluations     = 10
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 5
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 15
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 4
# Number of residual evaluations     = 10
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 5
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 14
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 11
# Number of residual evaluations     = 36
# Number of Jacobian evaluations     = 7
# Number of nonlinear iterations     = 18
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 20
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 8
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 4
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 10
#
#
# Final Run Statistics:
#
# Number of steps                    = 17
# Number of residual evaluations     = 52
# Number of Jacobian evaluations     = 9
# Number of nonlinear iterations     = 26
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 29
#
# Basis not feasible with primal status 4
#
# Final Run Statistics:
#
# Number of steps                    = 17
# Number of residual evaluations     = 52
# Number of Jacobian evaluations     = 9
# Number of nonlinear iterations     = 26
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 29
#
# Total simulation time was 16.6719 seconds
# cc1plus: warning: command line option '-Wstrict-prototypes' is valid for C/ObjC but not for C++
# Final Run Statistics:
#
# Number of steps                    = 37
# Number of residual evaluations     = 156
# Number of Jacobian evaluations     = 19
# Number of nonlinear iterations     = 76
# Number of error test failures      = 10
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 126
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 24
# Number of Jacobian evaluations     = 6
# Number of nonlinear iterations     = 12
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 18
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 8
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 4
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 9
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 4
# Number of Jacobian evaluations     = 1
# Number of nonlinear iterations     = 2
# Number of error test failures      = 0
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 22
# Number of residual evaluations     = 64
# Number of Jacobian evaluations     = 9
# Number of nonlinear iterations     = 32
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 32
#
#
# Final Run Statistics:
#
# Number of steps                    = 10
# Number of residual evaluations     = 36
# Number of Jacobian evaluations     = 7
# Number of nonlinear iterations     = 18
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 22
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 11
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 26
# Number of Jacobian evaluations     = 8
# Number of nonlinear iterations     = 13
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 18
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 9
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 26
# Number of Jacobian evaluations     = 8
# Number of nonlinear iterations     = 13
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 18
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 11
#
#
# Final Run Statistics:
#
# Number of steps                    = 8
# Number of residual evaluations     = 30
# Number of Jacobian evaluations     = 9
# Number of nonlinear iterations     = 15
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 20
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 9
#
#
# Final Run Statistics:
#
# Number of steps                    = 8
# Number of residual evaluations     = 30
# Number of Jacobian evaluations     = 9
# Number of nonlinear iterations     = 15
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 19
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 10
#
#
# Final Run Statistics:
#
# Number of steps                    = 9
# Number of residual evaluations     = 34
# Number of Jacobian evaluations     = 10
# Number of nonlinear iterations     = 17
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 20
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 10
#
#
# Final Run Statistics:
#
# Number of steps                    = 2
# Number of residual evaluations     = 10
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 5
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 26
# Number of Jacobian evaluations     = 8
# Number of nonlinear iterations     = 13
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 18
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 11
#
#
# Final Run Statistics:
#
# Number of steps                    = 3
# Number of residual evaluations     = 16
# Number of Jacobian evaluations     = 4
# Number of nonlinear iterations     = 8
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 13
#
#
# Final Run Statistics:
#
# Number of steps                    = 4
# Number of residual evaluations     = 14
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 7
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 15
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 8
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 4
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 8
#
#
# Final Run Statistics:
#
# Number of steps                    = 6
# Number of residual evaluations     = 22
# Number of Jacobian evaluations     = 7
# Number of nonlinear iterations     = 11
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 17
#
#
# Final Run Statistics:
#
# Number of steps                    = 5
# Number of residual evaluations     = 20
# Number of Jacobian evaluations     = 6
# Number of nonlinear iterations     = 10
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 15
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 11
#
#
# Final Run Statistics:
#
# Number of steps                    = 3
# Number of residual evaluations     = 16
# Number of Jacobian evaluations     = 4
# Number of nonlinear iterations     = 8
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 13
#
#
# Final Run Statistics:
#
# Number of steps                    = 8
# Number of residual evaluations     = 30
# Number of Jacobian evaluations     = 9
# Number of nonlinear iterations     = 15
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 19
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 11
#
#
# Final Run Statistics:
#
# Number of steps                    = 6
# Number of residual evaluations     = 22
# Number of Jacobian evaluations     = 7
# Number of nonlinear iterations     = 11
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 17
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 8
#
#
# Final Run Statistics:
#
# Number of steps                    = 5
# Number of residual evaluations     = 20
# Number of Jacobian evaluations     = 6
# Number of nonlinear iterations     = 10
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 16
#
#
# Final Run Statistics:
#
# Number of steps                    = 12
# Number of residual evaluations     = 42
# Number of Jacobian evaluations     = 10
# Number of nonlinear iterations     = 21
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 20
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 11
#
#
# Final Run Statistics:
#
# Number of steps                    = 18
# Number of residual evaluations     = 58
# Number of Jacobian evaluations     = 11
# Number of nonlinear iterations     = 29
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 24
#
# Basis not feasible with primal status 4
#
# Final Run Statistics:
#
# Number of steps                    = 18
# Number of residual evaluations     = 58
# Number of Jacobian evaluations     = 11
# Number of nonlinear iterations     = 29
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 24
#
# Total simulation time was 17.6719 seconds
# cc1plus: warning: command line option '-Wstrict-prototypes' is valid for C/ObjC but not for C++
# Final Run Statistics:
#
# Number of steps                    = 40
# Number of residual evaluations     = 166
# Number of Jacobian evaluations     = 20
# Number of nonlinear iterations     = 81
# Number of error test failures      = 11
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 139
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 8
# Number of Jacobian evaluations     = 2
# Number of nonlinear iterations     = 4
# Number of error test failures      = 1
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 10
#
#
# Final Run Statistics:
#
# Number of steps                    = 8
# Number of residual evaluations     = 32
# Number of Jacobian evaluations     = 9
# Number of nonlinear iterations     = 16
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 19
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 10
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 11
#
#
# Final Run Statistics:
#
# Number of steps                    = 21
# Number of residual evaluations     = 72
# Number of Jacobian evaluations     = 6
# Number of nonlinear iterations     = 36
# Number of error test failures      = 3
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 29
#
#
# Final Run Statistics:
#
# Number of steps                    = 11
# Number of residual evaluations     = 44
# Number of Jacobian evaluations     = 12
# Number of nonlinear iterations     = 22
# Number of error test failures      = 3
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 22
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 11
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 26
# Number of Jacobian evaluations     = 8
# Number of nonlinear iterations     = 13
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 18
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 9
#
#
# Final Run Statistics:
#
# Number of steps                    = 6
# Number of residual evaluations     = 22
# Number of Jacobian evaluations     = 7
# Number of nonlinear iterations     = 11
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 16
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 11
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 26
# Number of Jacobian evaluations     = 8
# Number of nonlinear iterations     = 13
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 18
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 9
#
#
# Final Run Statistics:
#
# Number of steps                    = 8
# Number of residual evaluations     = 30
# Number of Jacobian evaluations     = 9
# Number of nonlinear iterations     = 15
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 19
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 11
#
#
# Final Run Statistics:
#
# Number of steps                    = 8
# Number of residual evaluations     = 30
# Number of Jacobian evaluations     = 9
# Number of nonlinear iterations     = 15
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 19
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 11
#
#
# Final Run Statistics:
#
# Number of steps                    = 3
# Number of residual evaluations     = 16
# Number of Jacobian evaluations     = 4
# Number of nonlinear iterations     = 8
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 6
# Number of residual evaluations     = 24
# Number of Jacobian evaluations     = 7
# Number of nonlinear iterations     = 12
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 16
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 11
#
#
# Final Run Statistics:
#
# Number of steps                    = 3
# Number of residual evaluations     = 16
# Number of Jacobian evaluations     = 4
# Number of nonlinear iterations     = 8
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 12
#
#
# Final Run Statistics:
#
# Number of steps                    = 5
# Number of residual evaluations     = 20
# Number of Jacobian evaluations     = 6
# Number of nonlinear iterations     = 10
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 15
#
#
# Final Run Statistics:
#
# Number of steps                    = 6
# Number of residual evaluations     = 24
# Number of Jacobian evaluations     = 6
# Number of nonlinear iterations     = 12
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 17
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 8
#
#
# Final Run Statistics:
#
# Number of steps                    = 4
# Number of residual evaluations     = 18
# Number of Jacobian evaluations     = 4
# Number of nonlinear iterations     = 9
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 13
#
#
# Final Run Statistics:
#
# Number of steps                    = 2
# Number of residual evaluations     = 14
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 7
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 11
#
#
# Final Run Statistics:
#
# Number of steps                    = 7
# Number of residual evaluations     = 26
# Number of Jacobian evaluations     = 8
# Number of nonlinear iterations     = 13
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 18
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 9
#
#
# Final Run Statistics:
#
# Number of steps                    = 5
# Number of residual evaluations     = 20
# Number of Jacobian evaluations     = 6
# Number of nonlinear iterations     = 10
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 15
#
#
# Final Run Statistics:
#
# Number of steps                    = 5
# Number of residual evaluations     = 20
# Number of Jacobian evaluations     = 6
# Number of nonlinear iterations     = 10
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 15
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 11
#
#
# Final Run Statistics:
#
# Number of steps                    = 11
# Number of residual evaluations     = 42
# Number of Jacobian evaluations     = 10
# Number of nonlinear iterations     = 21
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 22
#
#
# Final Run Statistics:
#
# Number of steps                    = 1
# Number of residual evaluations     = 12
# Number of Jacobian evaluations     = 3
# Number of nonlinear iterations     = 6
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 10
#
#
# Final Run Statistics:
#
# Number of steps                    = 18
# Number of residual evaluations     = 64
# Number of Jacobian evaluations     = 10
# Number of nonlinear iterations     = 32
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 28
#
# Basis not feasible with primal status 4
#
# Final Run Statistics:
#
# Number of steps                    = 18
# Number of residual evaluations     = 64
# Number of Jacobian evaluations     = 10
# Number of nonlinear iterations     = 32
# Number of error test failures      = 2
# Number of nonlinear conv. failures = 0
# Number of root fn. evaluations     = 28
#
# Total simulation time was 18.3281 seconds

# %%
# Glc = [10,20,40,80]
# Prog = [0.21,0.407906,0.761817,1.480404]

# %%
plt.plot(Glc,Prog)
# plt.legend(])
plt.xlabel("GLC INITIAL CONC (mmol/L)")
plt.ylabel("PROGESTERONE TITRE (mmol/L)")
plt.title("The effect of initial glucose concentration \n on final progesterone titre")
# plt.savefig('figures/05_phase_plane.png',bbox_inches='tight')
plt.savefig('figures/07_linear_relation.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# As seen on the figure above, in our model there is a linear relation between added glucose initially and the final titre of progesterone that has been produced.
